# %%
import numpy as np
# import matplotlib.pyplot as plt

import random
import pickle as pkl
import gzip

import games
import synthetic_data
import evaluator

import neuralcbp_EE_kclasses_v6
import ineural_multi
import neuronal
import margin_based
import cesa_bianchi

# %%
case = 'case1' 
model = 'MLP' # or 'LeNet'
approach = 'EEneuralcbpside_v6'
context_type = 'adult' # or 'MNISTbinary', 'MagicTelescope', 'adult'
n_folds = 1
horizon = 500
seed = 1

if case == 'case1': # unitary binary classification: 'MNISTbinary', 'MagicTelescope', 'adult'
    game = games.game_case1( {} )

elif case == 'case1b': # FP-sensitive binary classification: 'MNISTbinary', 'MagicTelescope', 'adult'
    game = games.game_case1b( {} )

elif case == 'case2': # classification for 10 classes: 'MNIST', 'CIFAR10', 'Fashion'
    game = games.game_case2( {} )

elif case == 'game_case_seven': # classification for 7 classes: 'covertype', 'shuttle'
    game = games.game_case_seven( {} )


eval = evaluator.Evaluation(case, model, n_folds, horizon, game, approach, context_type)
eval.set_random_seeds(seed)


#################################### CONTEXT GENERATOR:

######## binary tasks

if context_type == 'MNISTbinary':
    context_generator = synthetic_data.MNISTcontexts_binary(eval)
    context_generator.initiate_loader()


elif context_type == 'adult':
    data = synthetic_data.Bandit_multi('adult') 
    context_generator = synthetic_data.CustomContexts(eval)
    context_generator.initiate_loader(data.X, data.y)
    

elif context_type == 'MagicTelescope':
    data = synthetic_data.Bandit_multi('MagicTelescope') 
    context_generator = synthetic_data.CustomContexts(eval)
    context_generator.initiate_loader(data.X, data.y)

############ 10-classes tasks

elif context_type == 'MNIST':
    context_generator = synthetic_data.MNISTcontexts(eval)
    context_generator.initiate_loader()

elif context_type == 'FASHION':
    context_generator = synthetic_data.FashionMNISTContexts(eval)
    context_generator.initiate_loader()

elif context_type == 'CIFAR10':
    context_generator = synthetic_data.CIFAR10Contexts(eval)
    context_generator.initiate_loader()


############# other tasks:

elif context_type == 'covertype':
    data = synthetic_data.Bandit_multi('covertype') 
    context_generator = synthetic_data.CustomContexts(eval)
    context_generator.initiate_loader(data.X, data.y)

elif context_type == 'shuttle':
    data = synthetic_data.Bandit_multi('shuttle') 
    context_generator = synthetic_data.CustomContexts(eval)
    context_generator.initiate_loader(data.X, data.y)

    

#################################### AGENT:

m = 100
nclasses = game.M

if approach == 'EEneuralcbpside_v6':
    alg = neuralcbp_EE_kclasses_v6.CBPside( game, context_type, eval.model, 1.01, m, nclasses,  'cuda:0')

elif approach == 'ineural3':
    budget = eval.horizon
    margin = 3
    alg = ineural_multi.INeurALmulti(budget, nclasses, margin, m, 'cuda:0')

elif approach == 'ineural6':
    budget = eval.horizon
    margin = 6
    alg = ineural_multi.INeurALmulti(budget, nclasses, margin, m, 'cuda:0')


elif approach == 'neuronal3':
    budget = eval.horizon
    margin = 3
    alg = neuronal.NeuronAL(eval.model,context_type, budget, nclasses, margin, True, m,'cuda:0')

elif approach == 'neuronal6':
    budget = eval.horizon
    margin = 6
    alg = neuronal.NeuronAL(eval.model,context_type,  budget, nclasses, margin, True, m, 'cuda:0')

if approach == 'margin':
    threshold = 0.1
    alg = margin_based.MarginBased(game, m, threshold,  'cuda:0')

elif approach == 'cesa':
    alg = cesa_bianchi.CesaBianchi(game, m, 'cuda:0')

alg.reset(context_generator.d)
# Out:
# (105,)
# num workers 1

# %%
job = context_generator, alg 
r = eval.eval_policy_once(game, job)
# Out:
# 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 1 [0, 1]
# t 0 action 0 outcome 1 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 1 action 1 outcome 1 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 2 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 3 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 4 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 5 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 6 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 7 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 8 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 9 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 10 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 11 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 12 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 13 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 14 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 15 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 16 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 17 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 18 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 19 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 20 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 21 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 22 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 23 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 24 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 25 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 26 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 27 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 28 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 29 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 30 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 31 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 32 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 33 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 34 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 35 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 36 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 37 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 38 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 39 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 40 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 41 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 42 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 43 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 44 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 45 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 46 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 47 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 48 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 49 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 50 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 51 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 52 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 53 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 54 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 55 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 56 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 57 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 58 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 59 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 60 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 61 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 62 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 63 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 64 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 65 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 66 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 67 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 68 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 69 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 70 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 71 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 72 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 73 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 74 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 75 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 76 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 77 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 78 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 79 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 80 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 81 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 82 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 83 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 84 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 85 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 86 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 87 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 88 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 89 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 90 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 91 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 92 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 93 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 94 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 95 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 96 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 97 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 98 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 99 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 100 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 101 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 102 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 103 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 104 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 105 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 106 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 107 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 108 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 109 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 110 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 111 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 112 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 113 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 114 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 115 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 116 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 117 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 118 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 119 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 120 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 121 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 122 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 123 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 124 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 125 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 126 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 127 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 128 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 129 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 130 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 131 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 132 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 133 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 134 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 135 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 136 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 137 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 138 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 139 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 140 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 141 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 142 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 143 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 144 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 145 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 146 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 147 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 148 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 149 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 150 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 151 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 152 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 153 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 154 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 155 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 156 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 157 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 158 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 159 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 160 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 161 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 162 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 163 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 164 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 165 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 166 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 167 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 168 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 169 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 170 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 171 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 172 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 173 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 174 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 175 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 176 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 177 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 178 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 179 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 180 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 181 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 182 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 183 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 184 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 185 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 186 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 187 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 188 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 189 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 190 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 191 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 192 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 193 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 194 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 195 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 196 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 197 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 198 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 199 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 200 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 201 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 202 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 203 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 204 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 205 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 206 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 207 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 208 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 209 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 210 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 211 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 212 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 213 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 214 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 215 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 216 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 217 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 218 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 219 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 220 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 221 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 222 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 223 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 224 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 225 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 226 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 227 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 228 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 229 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 230 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 231 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 232 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 233 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 234 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 235 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 236 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 237 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 238 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 239 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 240 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 241 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 242 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 243 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 244 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 245 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 246 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 247 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 248 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 249 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 250 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 251 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 252 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 253 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 254 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 255 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 256 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 257 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 258 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 259 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 260 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 261 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 262 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 263 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 264 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 265 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 266 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 267 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 268 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 269 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 270 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 271 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 272 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 273 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 274 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 275 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 276 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 277 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 278 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 279 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 280 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 281 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 282 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 283 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 284 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 285 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 286 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 287 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 288 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 289 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 290 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 291 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 292 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 293 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 294 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 295 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 296 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 297 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 298 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 299 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 300 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 301 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 302 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 303 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 304 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 305 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# ...
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 398 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 399 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 400 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 401 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 402 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 403 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 404 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 405 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 406 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 407 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 408 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 409 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 410 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 411 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 412 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 413 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 414 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 415 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 416 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 417 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 418 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 419 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 420 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 421 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 422 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 423 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 424 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 425 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 426 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 427 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 428 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 429 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 430 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 431 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 432 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 433 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 434 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 435 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 436 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 437 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 438 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 439 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 440 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 441 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 442 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 443 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 444 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 445 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 446 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 447 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 448 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 449 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 450 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 451 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 452 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 453 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 454 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 455 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 456 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 457 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 458 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 459 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 460 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 461 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 462 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 463 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 464 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 465 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 466 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 467 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 468 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 469 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 470 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 471 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 472 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 473 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 474 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 475 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 476 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 477 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 478 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 479 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 480 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 481 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 482 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 483 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 484 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 485 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 486 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 487 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 488 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 489 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 490 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 491 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 492 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 493 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 494 action 2 outcome 0 regret 1
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 495 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 496 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 497 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 498 action 2 outcome 1 regret 0
# torch.Size([1, 105])
# latent torch.Size([1, 100])
# P_t 1 [2] N_t []
# union1 [2] R []
# value {2: array([0.])}
# feedback 2 [0, 1]
# t 499 action 2 outcome 1 regret 0
