# %%
import os
import numpy as np
import plotly.graph_objects as go

import gzip
import pickle as pkl

def loadall_results2(path, n_folds):
    result = []#np.zeros( (n_folds, 20000) )
    with gzip.open(  path ,'rb') as f:
        for i in range(n_folds):
            try:
                result.append( pkl.load(f) ) #[:20000]
            except EOFError:
                break
    
    return np.array(result)

# %%
n_folds = 96
horizon = 20000


context_type = 'linear'

task = 'balanced'
name = 'LE'
labels_latex = [  'CBPside',  'RandCBP',    ] # 'PGIDS' 'RandCBP1' , 'PGIDS' 
labels = [  'CBPside',  'RandCBP2',   ] #'PGIDSratio' 'RandCBP1'  'PGIDSratio' 
colors = [ [0,0,0], [250,0,0],  [160, 32, 240] ]  

fig = go.Figure(    )

for color, label, label_latex in zip( colors, labels, labels_latex):

    r,g,b = color

    direct = './contextual_results/{}'.format(name)
    if label == 'RandCBP1':
        path = os.path.join(direct, 'benchmark_{}_{}_20000_96_RandCBPside005_1_10_07.pkl.gz'.format(task,context_type) )
        result = loadall_results2(path, 96)

    elif label == 'RandCBP2':
        path = os.path.join(direct, 'benchmark_{}_{}_20000_96_RandCBPside2005_1_10_07.pkl.gz'.format(task,context_type) )
        result = loadall_results2(path, 96)

    elif label == 'CBPside':
        print('hey')
        path = os.path.join(direct, 'benchmark_{}_{}_20000_96_CBPside005.pkl.gz'.format(task,context_type) )
        result = loadall_results2(path, 96)

    else: 
        # task = 'difficult' if task == 'balanced' else 'easy'
        # path = os.path.join(direct, '{}_{}_{}_{}_{}.pkl.gz'.format(task,context_type, horizon, 96, label) )
        # result = loadall_results(path, horizon, n_folds)
        path = os.path.join(direct, 'benchmark_balanced_linear_5000_96_PGIDSratio.pkl.gz'.format(task,context_type) )
        result = loadall_results2(path, 96)

    worst_case = np.argmax( result[:,-1] )
    regret =  np.mean(result,0) 
    std =  np.std(result,0)

    if label != 'PGIDSratio':
        xcoords = np.arange(0,horizon-1,1).tolist() 
        upper_regret = regret + std #result[worst_case]

        fig.add_trace(go.Scatter(x=xcoords, y=regret[:horizon-1], line=dict(color='rgb({},{},{})'.format(r,g,b)), mode='lines',  name=label_latex,legendgrouptitle_text='Algorithm',legendgroup='Algorithm' ,  showlegend=False )) # 

        fig.add_trace(   go.Scatter( x=xcoords+xcoords[::-1], y=upper_regret[:horizon-1].tolist()+regret[:horizon-1].tolist()[::-1],  fill='toself', fillcolor='rgba({},{},{},0.2)'.format(r,g,b), 
                            line=dict(color='rgba(255,255,255,0)'),   hoverinfo="skip",  showlegend=False )   )
    else:
        xcoords = np.arange(0,4999,1).tolist() 
        upper_regret = regret + std #result[worst_case]

        fig.add_trace(go.Scatter(x=xcoords, y=regret[:4999], line=dict(color='rgb({},{},{})'.format(r,g,b)), mode='lines',  name=label_latex,legendgrouptitle_text='Algorithm',legendgroup='Algorithm' ,  showlegend=False )) # 

        fig.add_trace(   go.Scatter( x=xcoords+xcoords[::-1], y=upper_regret[:4999].tolist()+regret[:4999].tolist()[::-1],  fill='toself', fillcolor='rgba({},{},{},0.2)'.format(r,g,b), 
                            line=dict(color='rgba(255,255,255,0)'),   hoverinfo="skip",  showlegend=False )   )



# Update the y-axis tick values and labels #3.5
fig.update_yaxes(type='log', range=[0, 5], tickvals=[1, 10, 100, 1000, 5000, 10000, 20000])


fig.update_layout( autosize=False,
                   xaxis_title="Sequence",
                   yaxis_title="Regret",
                   margin=go.layout.Margin( l=0,   r=0,   b=0,    t=0, ), 
                   font=dict(size=30,) ) #legend= dict(yanchor="top",y=0.98,xanchor="left",x=0.05)

# fig.update_yaxes(range=[0, 2.7] ) #5
# fig.update_yaxes( type="log" , dtick=0.1)
fig.show(legend=False)

fig.write_image("./{}_{}_{}.pdf".format(task, name, context_type)  )

# %%
n_folds = 96
horizon = 20000


context_type = 'linear'

task = 'balanced'
name = 'AT'
labels_latex = [  'CBPside',  'RandCBP',  'PGIDS'  ] # 'PGIDS' 'RandCBP1' , 'PGIDS' 
labels = [  'CBPside',  'RandCBP2', 'PGIDSratio'  ] #'PGIDSratio' 'RandCBP1'  'PGIDSratio' 
colors = [ [0,0,0], [250,0,0],  [160, 32, 240] ]  

fig = go.Figure(    )

for color, label, label_latex in zip( colors, labels, labels_latex):

    r,g,b = color

    direct = './contextual_results/{}'.format(name)
    if label == 'RandCBP1':
        path = os.path.join(direct, 'benchmark_{}_{}_20000_96_RandCBPside005_1_10_07.pkl.gz'.format(task,context_type) )
        result = loadall_results2(path, 96)

    elif label == 'RandCBP2':
        path = os.path.join(direct, 'benchmark_{}_{}_20000_96_RandCBPside2005_1_10_07.pkl.gz'.format(task,context_type) )
        result = loadall_results2(path, 96)

    elif label == 'CBPside':
        print('hey')
        path = os.path.join(direct, 'benchmark_{}_{}_20000_96_CBPside005.pkl.gz'.format(task,context_type) )
        result = loadall_results2(path, 96)

    else: 
        # task = 'difficult' if task == 'balanced' else 'easy'
        # path = os.path.join(direct, '{}_{}_{}_{}_{}.pkl.gz'.format(task,context_type, horizon, 96, label) )
        # result = loadall_results(path, horizon, n_folds)
        path = os.path.join(direct, 'benchmark_balanced_linear_7500_96_PGIDSratio.pkl.gz'.format(task,context_type) )
        result = loadall_results2(path, 96)

    worst_case = np.argmax( result[:,-1] )
    regret =  np.mean(result,0) 
    std =  np.std(result,0)

    if label != 'PGIDSratio':
        xcoords = np.arange(0,horizon-1,1).tolist() 
        upper_regret = regret + std #result[worst_case]

        fig.add_trace(go.Scatter(x=xcoords, y=regret[:horizon-1], line=dict(color='rgb({},{},{})'.format(r,g,b)), mode='lines',  name=label_latex,legendgrouptitle_text='Algorithm',legendgroup='Algorithm' ,  showlegend=False )) # 

        fig.add_trace(   go.Scatter( x=xcoords+xcoords[::-1], y=upper_regret[:horizon-1].tolist()+regret[:horizon-1].tolist()[::-1],  fill='toself', fillcolor='rgba({},{},{},0.2)'.format(r,g,b), 
                            line=dict(color='rgba(255,255,255,0)'),   hoverinfo="skip",  showlegend=False )   )
    else:
        xcoords = np.arange(0,7499,1).tolist() 
        upper_regret = regret + std #result[worst_case]

        fig.add_trace(go.Scatter(x=xcoords, y=regret[:7499], line=dict(color='rgb({},{},{})'.format(r,g,b)), mode='lines',  name=label_latex,legendgrouptitle_text='Algorithm',legendgroup='Algorithm' ,  showlegend=False )) # 

        fig.add_trace(   go.Scatter( x=xcoords+xcoords[::-1], y=upper_regret[:7499].tolist()+regret[:7499].tolist()[::-1],  fill='toself', fillcolor='rgba({},{},{},0.2)'.format(r,g,b), 
                            line=dict(color='rgba(255,255,255,0)'),   hoverinfo="skip",  showlegend=False )   )



# Update the y-axis tick values and labels #3.5
fig.update_yaxes(type='log', range=[0, 3.7], tickvals=[1, 10, 100, 1000, 10000, 20000])


fig.update_layout( autosize=False,
                   xaxis_title="Sequence",
                   yaxis_title="Regret",
                   margin=go.layout.Margin( l=0,   r=0,   b=0,    t=0, ), 
                   font=dict(size=30,) ) #legend= dict(yanchor="top",y=0.98,xanchor="left",x=0.05)

# fig.update_yaxes(range=[0, 2.7] ) #5
# fig.update_yaxes( type="log" , dtick=0.1)
fig.show(legend=False)

fig.write_image("./{}_{}_{}.pdf".format(task, name, context_type)  )

# %%
def loadall_results2(path, n_folds):
    result = []#np.zeros( (n_folds, 20000) )
    with gzip.open(  path ,'rb') as f:
        for i in range(n_folds):
            try:
                result.append( pkl.load(f)[:19999] )
            except EOFError:
                break
    
    return np.array(result)

n_folds = 96
horizon = 20000

labels = [   'RandCBP', 'CBP'  ]  

final_regrets = {}

game = 'LE'
task = 'balanced'

for label in labels:

    if label == 'RandCBP':
        direct = './contextual_results/{}/'.format(game)
        path = os.path.join(direct, 'benchmark_{}_linear_20000_96_RandCBPside2005_1_10_07.pkl.gz'.format(task) )
        result = loadall_results2(path, horizon)
    else: 
        direct = './contextual_results/{}/'.format(game)
        path = os.path.join(direct, 'benchmark_{}_linear_20000_96_CBPside005.pkl.gz'.format(task) )
        result = loadall_results2(path, horizon)

    final_regrets[label] =  result[:,-1] 

final = np.array( [ (1, i) if final_regrets['RandCBP'][i] < final_regrets['CBP'][i] else (0, i) for i in range(n_folds) ] )

print( '{} {}'.format(game, task),sum(final[:,0]) )
# Out:
# LE balanced 96

# %%
final_regrets
# Out:
# {'RandCBP': array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan]),
#  'CBP': array([1486.75747484, 1480.92531206, 1596.06970745, 1578.19217608,
#         1563.83868448, 1490.27317573, 1589.57197454, 1463.33981417,
#         1534.6330111 , 1440.67287649, 1534.38520661, 1569.73958635,
#         1507.38533437, 1550.6196211 , 1461.78292912, 1562.46411294,
#         1450.90954444, 1575.27658276, 1462.65361107, 1552.10777343,
#         1461.43762946, 1537.75319944, 1540.10780101, 1458.07107368,
# ...

# %%
def loadall_results(path, n_folds):
    results = []
    with gzip.open(  path ,'rb') as f:
        for i in range(n_folds):
            try:
                result = pkl.load(f)
                results.append( result[-1] )
            except EOFError:
                break
    return result


n_folds = 96
horizon = 100000
task = 'easy'# 'easy' #'difficult'
context_type = 'linear'
name = 'AT'

labels = [  'CBP', 'RandCBP'  ]  

final_regrets = {}


direct = './contextual_results/{}'.format(name)
for label in labels:

    if label == 'RandCBP':
        path = os.path.join(direct, 'benchmark_{}_{}_100000_96_RandCBPside005_1_10_07.pkl.gz'.format(task,context_type) )
        result = loadall_results(path, n_folds)
        final_regrets[label] =  result
    else: 
        path = os.path.join(direct, '{}_{}_100000_96_CBPside005.pkl.gz'.format(task,context_type) )
        result = loadall_results(path, n_folds)
        final_regrets[label] =  result

final = np.array( [ (1, i) if final_regrets['RandCBP'][i] <= final_regrets['CBP'][i] else (0, i) for i in range(n_folds) ] )

print( '{}'.format(task),sum(final[:,0]) )


# final_regrets = {}

# for label in labels:

#     if label == 'RandCBP':
#         result = np.load( './results/benchmark_randcbp/AT/easy_{}_{}_Gaussian_1_10_10e7.npy'.format(horizon,n_folds, label) )
#     else: 
#         result = np.load( './results/AT/easy_{}_{}_{}.npy'.format(horizon,n_folds, label) )

#     final_regrets[label] =  result[:,-1] 

# final = np.array( [ (1, i) if final_regrets['RandCBP'][i] < final_regrets['CBP'][i] else (0, i) for i in range(n_folds) ] )

# print( 'easy ',sum(final[:,0]) )
# Out:
# easy 96
